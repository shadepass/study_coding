# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
print(df.head())
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %%
df.tail()
# Out:
#                                                    title       channelTitle  \
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트                 공룡
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...            놀면 뭐하니?
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)  김종국 GYM JONG KOOK
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...           스브스 예능맛집
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV        HYBE LABELS
#
#        categoryId  view_count    likes  dislikes  comment_count  \
# 60394          22      538190    16671       209           3117
# 60395          24     1607562    14615       258           1141
# 60396          17     1125911    26490       263           1915
# 60397          24     1741773    14994       304            802
# 60398          10    13753485  1784532      9737         195461
#
#                       channelId trending_date2
# 60394  UCWf4QKgnTyvmehcRqw-JldQ     2021-10-19
# ...

# %%
df.channelTitle.value_counts().index[:10]
# Out:
# Index(['짤툰', '파뿌리', 'SPOTV', '런닝맨 - 스브스 공식 채널', '엠뚜루마뚜루 : MBC 공식 종합 채널', '장삐쭈',
#        'BANGTANTV', '채널 십오야', '이과장', '총몇명'],
#       dtype='object', name='channelTitle')

# %%
df.loc[df.dislikes >= df.likes].channelTitle.unique()
# Out:
# array(["RAIN's Official Channel", 'STARNEWS KOREA', '김숙티비kimsookTV',
#        '베러심플_Better simple', 'GQ KOREA', '핫도그TV', '[Nareum_TV] 나름TV',
#        '파이널판타지14', '모비딕 Mobidic', 'Samsung', 'SBS Radio 에라오', 'ASMR 애정TV',
#        'TOHO animation チャンネル', 'JINI YUM', '[Dorothy]도로시',
#        '하얀트리HayanTree', '박병일의 명장본색', '꿀주부 Honeyjubu', '양팡 YangPang',
#        '철구형 (CHULTUBE)', 'SuperM', '왜냐맨하우스', 'NewsInStar', 'THE BOYZ',
#        '스튜디오 와플 - STUDIO WAFFLE', '망구 MANGOO', 'LCK', 'Brave Girls',
#        'Brave Girls 브레이브걸스', 'GoogleDoodles', '이루리 ILULIY', '이데일리 edaily',
#        '(MUTUBE)와꾸대장봉준', '오메킴TV', 'OH MY GIRL', '육지담', 'MapleStory_KR',
#        'ROAD FIGHTING CHAMPIONSHIP', '여정을떠난여정', '사나이 김기훈', '수리키친Suri',
#        '조여사전성시대', 'YouTube', '허스토리 KBS', 'Brave Entertainment',
#        'BTOB 비투비 (Official YouTube Channel)', '나혼자산다 STUDIO', '대한민국공군',
#        'Gen.G esports', '머몌밈', 'Mnet TV', '골프존', '모스트콘텐츠 MOSTCONTENTS',
#        '한국닌텐도 공식 채널'], dtype=object)

# %%
df
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %%
df
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %%
temp = df.drop_duplicates(["channelTitle", "channelId"]).channelId.value_counts()

len(temp[temp >= 2])
# Out:
# 71

# %%
df
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %%
df.trending_date2 = pd.to_datetime(df.trending_date2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60399 entries, 0 to 60398
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           60399 non-null  object
#  1   channelTitle    60399 non-null  object
#  2   categoryId      60399 non-null  int64
#  3   view_count      60399 non-null  int64
#  4   likes           60399 non-null  int64
#  5   dislikes        60399 non-null  int64
#  6   comment_count   60399 non-null  int64
#  7   channelId       60399 non-null  object
#  8   trending_date2  60399 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(5), object(3)
# memory usage: 4.6+ MB

# %%
df2 = df.copy()
df2["day_name"] = df.trending_date2.dt.day_name()
df2.loc[df2.day_name == "Sunday"].categoryId.value_counts().index[0]
# Out:
# 24

# %%
temp = df2.groupby(["categoryId", "day_name"], as_index = False).size()
#answer = temp.pivot(index = "categoryId", columns = "day_name").set_columns("a")
#answer
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[72], line 2
#       1 temp = df2.groupby(["categoryId", "day_name"], as_index = False).size()
# ----> 2 answer = temp.pivot(index = "categoryId", columns = "day_name").set_columns("a")
#       3 answer
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'set_columns'

# %%
df
# Out:
#                                                    title  \
# 0                                              [신병] 물자창고
# 1       RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV
# 2           2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.
# 3                                           고기남자의 칠면조 파티
# 4      골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...
# ...                                                  ...
# 60394                       *풀코스로 먹습니다* 🍗치킨 + 🍕피자 + 🥧디저트
# 60395  [놀면 뭐하니? 예고] 우린 깐부잖아🦑 놀뭐에 등장한 월드클래스 초대손님!! MBC...
# 60396                   먹방 전쟁 : 사랑스러War (feat. 401 정육식당)
# 60397  ＂너.. 광수지?＂ 협상에 거짓말부터 던지는 광수 닮은꼴 김연경 선수 [런닝맨|21...
# 60398          ENHYPEN (엔하이픈) 'Tamed-Dashed' Official MV
#
#                   channelTitle  categoryId  view_count    likes  dislikes  \
# 0                          장삐쭈          23     1893473    38249       730
# 1      RAIN's Official Channel          10     2600864        0         0
# ...

# %%
temp = df.loc[df.view_count != 0].comment_count / df.loc[df.view_count != 0].view_count
f_index = temp.sort_values().index[-1]
df.loc[df.index == f_index].iloc[0, 0]
# Out:
# '60분 동안 댓글이 달리지 않으면, 영상이 삭제됩니다. (챌린지)'

# %%
temp = df.loc[(df.likes != 0) & (df.dislikes != 0)].dislikes / df.loc[(df.likes != 0) & (df.dislikes != 0)].likes
#temp
print(temp.sort_values())

f_index = temp.sort_values().index[0]

df.loc[df.index == f_index].iloc[0].title
# Out:
# 11477     0.000523
# 12168     0.000598
# 11969     0.000602
# 11740     0.000620
# 12386     0.000626
#            ...
# 26887    12.657785
# 27108    12.807119
# 27355    12.936469
# 27578    13.009868
# 27789    13.082719
# Length: 59693, dtype: float64
# '[줌터뷰] *최초공개* 사부작즈🐰🐶의 비공식 이름은 아이라인즈? 꿀조합 티키타카 가득한 NCT 127 도영&정우의 줌터뷰'

# %%
temp = df.title.value_counts()
len(temp[temp>=20])
# Out:
# 41

# %%
temp = df[["title", "channelId"]].value_counts()
len(temp[temp >= 20])
# Out:
# 40
